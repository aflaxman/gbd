# %% [markdown]
# Book graphics-------------This notebook holds the code location for all of the DisMod-MR book graphics.

# %%
cd ..
# Out:
# /snfs2/HOME/peterhm/gbd

# %%
# parkinsons-data, parkinsons-best%run book/graphics_parkinsons
# Out:
# kept 578 rows of data

# %%
# schiz_forest%run book/schiz_forest
# Out:
# WARNING: row 24 &lt;= 0
# WARNING: row 42 &lt;= 0
# WARNING: row 60 &lt;= 0
# WARNING: row 61 &lt;= 0
# WARNING: row 76 &lt;= 0
# WARNING: row 78 &lt;= 0
# WARNING: row 99 &lt;= 0
# WARNING: row 114 &lt;= 0
# WARNING: row 115 &lt;= 0
# WARNING: row 117 &lt;= 0
# WARNING: row 152 &lt;= 0
# WARNING: row 153 &lt;= 0
# WARNING: row 264 &lt;= 0
# WARNING: row 265 &lt;= 0
# Sampling:   0% [                                                ] Iterations: 0Sampling:   1% [                                              ] Iterations: 200Sampling:   2% [                                              ] Iterations: 400Sampling:   3% [0                                             ] Iterations: 600
# ...

# %%
# binomial-model-funnel, binomial-model-ppc%run book/binomial_model

# %%
# beta-distribution, beta-binomial-funnel%run book/beta_binomial

# %%
# poisson_approx_to_binom %run book/poisson_module

# %%
# negative_binomial_funnel%run book/neg_binomial_model

# %%
# ssas-mx_femaile_1990, splines-fig, level_value-smoothing-splines, level_bound-smoothing-splines, monotone-smoothing-splines%run book/splines

# %%
# af_age_groups_scatter%run book/af_age_groups

# %%
# af_ages_intervals%run book/age_intervals

# %%
# age_group_midpoint%run book/age_group_midpoint

# %%
# age_group_disagg%run book/age_group_disagg

# %%
# age_group_midpoint_covariate%run book/age_group_midpoint_cov

# %%
# age_group_standardize%run book/age_group_standardize

# %%
# age_group_models%run book/age_group_models

# %%
# cov_fe%run book/cov_fe_model

# %%
# bipolar-data-by-cv, bipolar-ref-alts%run book/bipolar_ex

# %%
# S# book/S.svg

# %%
# one_compartment_consistent, one_compartment_varying%run book/one_compartment

# %%
# SC# book/SC.svg

# %%
# initial, more-excess-mortality, birth-prevalence%run book/two_compartment_forward_sim

# %%
# forward-sim-mental, forward-sim-congenital, forward-sim-old-age, forward-sim-reproductive, forward-sim-incidence-pulse%run book/two_compartment_forward_sim_2

# %%
# gibbs-ball, metropolis-ball, am-ball-2%run book/ball

# %%
# cocaine_dependence-data, cocaine_dependence-knots, cocaine_dependence-smoothing%run book/graphics_cocaine_dependence
# Out:
# kept 24 rows of datakept 24 rows of data

# %%
# pms-data, pms-priors, pms-knot_location, pms-direction, pms-best_model%run book/graphics_pms
# Out:
# kept 106 rows of data

# %%
# af-data, af-mp_v_hetero_srt_p, af-mp_v_hetero_srt_i, af-best_model%run book/graphics_af
# Out:
# kept 247 rows of data

# %%
# hepc-EGY_v_JOR, hepc-region_v_EGY_v_JOR, hepc-tree_plot_global_hetero%run book/graphics_hepc
# Out:
# kept 38 rows of datakept 5 rows of data
# adding smoothing of
#  1.0using stored FE for
#  beta_p_x_sex x_sex {&apos;mu&apos;: 0.0, &apos;dist&apos;: &apos;Constant&apos;}

# %%
# anxiety-data_by_cv, anxiety-FE%run book/graphics_anxiety
# Out:
# kept 62 rows of datakept 62 rows of data

# %%
# cirrhosis-data, cirrhosis-lnASDR_v_prev%run book/graphics_cirrhosis
# Out:
# kept 52 rows of datakept 0 rows of data

# %%
# pancreatitis-we_data, pancreatitis-we_compare%run book/graphics_panc
# Out:
# kept 1182 rows of datakept 79 rows of data
# kept 62 rows of data
# kept 34 rows of data
# kept 0 rows of data

# %%
# fruit-rate_type, fruit-we_rate_type%run book/graphics_fruit_rt_we_rt
# Out:
# kept 11 rows of datakept 139 rows of data
# kept 139 rows of data
# kept 21 rows of data

# %%
# fruit-isl_rate_type%run book/graphics_fruit_isl_rt_type# note: ipy notebook does not display this figure correctly!!# but the saved pdf is correct (it has legends)

# %%
# ckd-data, ckd-incon_v_con, ckd-m_with_smoothing, ckd-asp_scatter%run book/graphics_ersd
# Out:
# kept 1268 rows of datakept 188 rows of data
# kept 1268 rows of data
# kept 188 rows of data

# %%
# oa_knee-knots, oa_knee-i_prior%run book/graphics_oa_knee
# Out:
# kept 109 rows of data

# %%
# bipolar-data, bipolar-bounds, bipolar-45_65_100, bipolar-0_5_10%run book/graphics_bipolar
# Out:
# kept 124 rows of data

# %%
# alcohol-data, alcohol-overlay%run book/graphics_alcohol
# Out:
# kept 103 rows of data
